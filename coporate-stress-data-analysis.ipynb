# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
corporate_df = pd.read_csv("corporate_stress_dataset.csv")
corporate_df
# Out:
#           ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0          1   56  Non-Binary        Widowed  Developer                 5
# 1          2   46      Female         Single    Analyst                20
# 2          3   32      Female         Single  Developer                10
# 3          4   60      Female       Divorced    Analyst                26
# 4          5   25        Male        Married      Sales                29
# ...      ...  ...         ...            ...        ...               ...
# 49995  49996   43      Female        Widowed         HR                 8
# 49996  49997   45        Male         Single    Analyst                31
# 49997  49998   43      Female       Divorced    Manager                 7
# 49998  49999   62        Male        Married         HR                 9
# 49999  50000   19      Female       Divorced    Manager                 0
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...

# %%
corporate_df.shape
# Out:
# (50000, 30)

# %%
corporate_df.drop("ID", axis=1, inplace=True)
corporate_df.describe()
# Out:
#                 Age  Experience_Years  Monthly_Salary_INR  \
# count  50000.000000      50000.000000        50000.000000
# mean      41.518600         20.071580       110129.926165
# std       13.833279         11.835681        52069.676542
# min       18.000000          0.000000        20001.960000
# 25%       30.000000         10.000000        64875.487500
# 50%       41.000000         20.000000       110168.205000
# 75%       54.000000         30.000000       155322.665000
# max       65.000000         40.000000       199992.800000
#
#        Working_Hours_per_Week  Commute_Time_Hours  Stress_Level   Sleep_Hours  \
# count             50000.00000        50000.000000  50000.000000  50000.000000
# mean                 62.53824            1.500454      5.004680      6.498888
# std                  16.16981            0.867738      3.154745      1.437200
# min                  35.00000            0.000000      0.000000      4.000000
# ...

# %%
corporate_df.isna().sum()
# Out:
# Age                                     0
# Gender                                  0
# Marital_Status                          0
# Job_Role                                0
# Experience_Years                        0
# Monthly_Salary_INR                      0
# Working_Hours_per_Week                  0
# Commute_Time_Hours                      0
# Remote_Work                             0
# Stress_Level                            0
# Health_Issues                       12541
# Company_Size                            0
# Department                              0
# Sleep_Hours                             0
# Physical_Activity_Hours_per_Week        0
# Mental_Health_Leave_Taken               0
# Manager_Support_Level                   0
# Work_Pressure_Level                     0
# Annual_Leaves_Taken                     0
# Work_Life_Balance                       0
# Family_Support_Level                    0
# Job_Satisfaction                        0
# ...

# %%
corporate_df.dtypes
# Out:
# Age                                   int64
# Gender                               object
# Marital_Status                       object
# Job_Role                             object
# Experience_Years                      int64
# Monthly_Salary_INR                  float64
# Working_Hours_per_Week                int64
# Commute_Time_Hours                  float64
# Remote_Work                            bool
# Stress_Level                          int64
# Health_Issues                        object
# Company_Size                         object
# Department                           object
# Sleep_Hours                         float64
# Physical_Activity_Hours_per_Week    float64
# Mental_Health_Leave_Taken              bool
# Manager_Support_Level                 int64
# Work_Pressure_Level                   int64
# Annual_Leaves_Taken                   int64
# Work_Life_Balance                     int64
# Family_Support_Level                  int64
# ...

# %%
corporate_df["Health_Issues"].unique()
# Out:
# array([nan, 'Physical', 'Mental', 'Both'], dtype=object)

# %%
corporate_df = corporate_df.fillna("No Issues")

# %%
corporate_df.isna().sum()
# Out:
# Age                                 0
# Gender                              0
# Marital_Status                      0
# Job_Role                            0
# Experience_Years                    0
# Monthly_Salary_INR                  0
# Working_Hours_per_Week              0
# Commute_Time_Hours                  0
# Remote_Work                         0
# Stress_Level                        0
# Health_Issues                       0
# Company_Size                        0
# Department                          0
# Sleep_Hours                         0
# Physical_Activity_Hours_per_Week    0
# Mental_Health_Leave_Taken           0
# Manager_Support_Level               0
# Work_Pressure_Level                 0
# Annual_Leaves_Taken                 0
# Work_Life_Balance                   0
# Family_Support_Level                0
# Job_Satisfaction                    0
# Performance_Rating                  0
# Team_Size                           0
# Training_Opportunities              0
# ...

# %%
corporate_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
corporate_df["Job_Role"].value_counts()
# Out:
# Job_Role
# Manager      8465
# Sales        8376
# Developer    8368
# Analyst      8335
# HR           8274
# Support      8182
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.histplot(corporate_df["Stress_Level"], kde = True)
plt.title("Distribution of Stress Level")
plt.show()

# %%
numerical_features = corporate_df.select_dtypes(include=np.number).columns.tolist()

print(numerical_features)
# Out:
# ['Age', 'Experience_Years', 'Monthly_Salary_INR', 'Working_Hours_per_Week', 'Commute_Time_Hours', 'Stress_Level', 'Sleep_Hours', 'Physical_Activity_Hours_per_Week', 'Manager_Support_Level', 'Work_Pressure_Level', 'Annual_Leaves_Taken', 'Work_Life_Balance', 'Family_Support_Level', 'Job_Satisfaction', 'Performance_Rating', 'Team_Size']
